# %% [markdown]
# # CtrlFreeQ API Demo
#
# This notebook demonstrates how to use the CtrlFreeQ API for quantum control optimization.
# The API provides a simple interface to load configuration files and run CtrlFreeQ optimizations.

# %%
# Import the CtrlFreeQ API
from ctrl_freeq.api import (
    load_config,
    run_from_config,
    load_single_qubit_config,
    load_single_qubit_multiple_config,
    load_two_qubit_config,
    load_two_qubit_multiple_config,
)
import matplotlib.pyplot as plt

from ctrl_freeq.visualisation.plotter import process_and_plot

# %% [markdown]
# ## 1. Single Qubit Optimization
#
# Let's start with a simple single qubit optimization example.

# %%
# Load single qubit configuration
single_qubit_api = load_single_qubit_config()

# Display configuration summary
print("Single Qubit Configuration:")
print("=" * 40)
print(single_qubit_api.get_config_summary())
# Out:
# Single Qubit Configuration:
# ========================================
# Number of qubits: 1
# Optimization space: hilbert
# Algorithm: qiskit-cobyla
# Max iterations: 1000
# Target fidelity: 0.999
# Initial states: [['Z']]
# Target Axis: [['-Z']]

# %%
# Run the optimization
print("Running single qubit optimization...")
single_qubit_solution = single_qubit_api.run_optimization()
print(f"Optimization completed. Solution shape: {single_qubit_solution.shape}")
print(f"Solution: {single_qubit_solution}")
waveforms = process_and_plot(
    single_qubit_solution, single_qubit_api.parameters, show_plots=True
)
# Out:
# Number of threads set to 11 out of 12 available cores.
# =================================
# Iteration  | Fidelity   | Penalty
# =================================
# 1          | 0.2143     | 0.0000
# 2          | 0.1747     | 0.0000
# 3          | 0.1643     | 0.0000
# 4          | 0.7686     | 0.0000
# 5          | 0.9511     | 0.0000
# 6          | 0.4406     | 0.0000
# 7          | 0.9444     | 0.0000
# 8          | 0.4863     | 0.0000
# 9          | 0.7744     | 0.0000
# 10         | 0.7367     | 0.0000
# 11         | 0.6513     | 0.0000
# 12         | 0.9349     | 0.0000
# 13         | 0.8055     | 0.0000
# 14         | 0.3162     | 0.0000
# 15         | 0.6581     | 0.0000
# 16         | 0.9102     | 0.0000
# 17         | 0.8720     | 0.0000
# 18         | 0.9137     | 0.0000
# 19         | 0.6968     | 0.0000
# 20         | 0.9533     | 0.0000
# 21         | 0.9529     | 0.0000
# 22         | 0.9527     | 0.0000
# 23         | 0.9385     | 0.0000
# 24         | 0.9479     | 0.0000
# 25         | 0.9508     | 0.0000
# 26         | 0.9511     | 0.0000
# 27         | 0.9548     | 0.0000
# 28         | 0.9361     | 0.0000
# 29         | 0.9501     | 0.0000
# 30         | 0.9581     | 0.0000
# 31         | 0.9605     | 0.0000
# 32         | 0.9618     | 0.0000
# 33         | 0.9627     | 0.0000
# 34         | 0.9579     | 0.0000
# 35         | 0.9633     | 0.0000
# 36         | 0.9642     | 0.0000
# 37         | 0.9524     | 0.0000
# 38         | 0.9633     | 0.0000
# 39         | 0.9596     | 0.0000
# 40         | 0.9648     | 0.0000
# 41         | 0.9566     | 0.0000
# 42         | 0.9651     | 0.0000
# 43         | 0.9520     | 0.0000
# 44         | 0.9642     | 0.0000
# 45         | 0.9601     | 0.0000
# 46         | 0.9662     | 0.0000
# 47         | 0.9643     | 0.0000
# 48         | 0.9680     | 0.0000
# 49         | 0.9606     | 0.0000
# 50         | 0.9670     | 0.0000
# 51         | 0.9655     | 0.0000
# 52         | 0.9661     | 0.0000
# 53         | 0.9680     | 0.0000
# 54         | 0.9677     | 0.0000
# 55         | 0.9680     | 0.0000
# 56         | 0.9679     | 0.0000
# 57         | 0.9682     | 0.0000
# 58         | 0.9684     | 0.0000
# 59         | 0.9684     | 0.0000
# 60         | 0.9684     | 0.0000
# 61         | 0.9685     | 0.0000
# 62         | 0.9686     | 0.0000
# Running single qubit optimization...
# 63         | 0.9684     | 0.0000
# 64         | 0.9686     | 0.0000
# 65         | 0.9686     | 0.0000
# 66         | 0.9690     | 0.0000
# 67         | 0.9696     | 0.0000
# 68         | 0.9699     | 0.0000
# 69         | 0.9703     | 0.0000
# 70         | 0.9706     | 0.0000
# 71         | 0.9708     | 0.0000
# 72         | 0.9710     | 0.0000
# 73         | 0.9709     | 0.0000
# 74         | 0.9710     | 0.0000
# 75         | 0.9712     | 0.0000
# 76         | 0.9716     | 0.0000
# 77         | 0.9719     | 0.0000
# 78         | 0.9724     | 0.0000
# 79         | 0.9727     | 0.0000
# 80         | 0.9726     | 0.0000
# 81         | 0.9727     | 0.0000
# 82         | 0.9730     | 0.0000
# 83         | 0.9730     | 0.0000
# 84         | 0.9733     | 0.0000
# 85         | 0.9739     | 0.0000
# 86         | 0.9744     | 0.0000
# 87         | 0.9748     | 0.0000
# 88         | 0.9751     | 0.0000
# 89         | 0.9755     | 0.0000
# 90         | 0.9760     | 0.0000
# 91         | 0.9763     | 0.0000
# 92         | 0.9767     | 0.0000
# 93         | 0.9770     | 0.0000
# 94         | 0.9773     | 0.0000
# 95         | 0.9776     | 0.0000
# 96         | 0.9778     | 0.0000
# 97         | 0.9780     | 0.0000
# 98         | 0.9782     | 0.0000
# 99         | 0.9779     | 0.0000
# 100        | 0.9782     | 0.0000
# 101        | 0.9783     | 0.0000
# 102        | 0.9789     | 0.0000
# 103        | 0.9793     | 0.0000
# 104        | 0.9797     | 0.0000
# 105        | 0.9800     | 0.0000
# 106        | 0.9803     | 0.0000
# 107        | 0.9803     | 0.0000
# 108        | 0.9802     | 0.0000
# 109        | 0.9803     | 0.0000
# 110        | 0.9808     | 0.0000
# 111        | 0.9807     | 0.0000
# 112        | 0.9809     | 0.0000
# 113        | 0.9812     | 0.0000
# 114        | 0.9815     | 0.0000
# 115        | 0.9817     | 0.0000
# 116        | 0.9820     | 0.0000
# 117        | 0.9821     | 0.0000
# 118        | 0.9824     | 0.0000
# 119        | 0.9824     | 0.0000
# 120        | 0.9825     | 0.0000
# 121        | 0.9824     | 0.0000
# 122        | 0.9825     | 0.0000
# 123        | 0.9824     | 0.0000
# 124        | 0.9826     | 0.0000
# 125        | 0.9826     | 0.0000
# 126        | 0.9829     | 0.0000
# 127        | 0.9832     | 0.0000
# 128        | 0.9830     | 0.0000
# 129        | 0.9831     | 0.0000
# 130        | 0.9836     | 0.0000
# 131        | 0.9840     | 0.0000
# 132        | 0.9843     | 0.0000
# 133        | 0.9847     | 0.0000
# 134        | 0.9851     | 0.0000
# 135        | 0.9853     | 0.0000
# 136        | 0.9858     | 0.0000
# 137        | 0.9860     | 0.0000
# 138        | 0.9860     | 0.0000
# 139        | 0.9861     | 0.0000
# 140        | 0.9866     | 0.0000
# 141        | 0.9867     | 0.0000
# 142        | 0.9868     | 0.0000
# 143        | 0.9869     | 0.0000
# 144        | 0.9871     | 0.0000
# 145        | 0.9873     | 0.0000
# 146        | 0.9873     | 0.0000
# 147        | 0.9875     | 0.0000
# 148        | 0.9877     | 0.0000
# 149        | 0.9880     | 0.0000
# 150        | 0.9885     | 0.0000
# 151        | 0.9888     | 0.0000
# 152        | 0.9890     | 0.0000
# 153        | 0.9892     | 0.0000
# 154        | 0.9893     | 0.0000
# 155        | 0.9891     | 0.0000
# 156        | 0.9894     | 0.0000
# 157        | 0.9897     | 0.0000
# 158        | 0.9899     | 0.0000
# 159        | 0.9902     | 0.0000
# 160        | 0.9902     | 0.0000
# 161        | 0.9905     | 0.0000
# 162        | 0.9908     | 0.0000
# 163        | 0.9909     | 0.0000
# 164        | 0.9911     | 0.0000
# 165        | 0.9913     | 0.0000
# 166        | 0.9915     | 0.0000
# 167        | 0.9914     | 0.0000
# 168        | 0.9916     | 0.0000
# 169        | 0.9915     | 0.0000
# 170        | 0.9918     | 0.0000
# 171        | 0.9919     | 0.0000
# 172        | 0.9919     | 0.0000
# 173        | 0.9918     | 0.0000
# 174        | 0.9923     | 0.0000
# 175        | 0.9925     | 0.0000
# 176        | 0.9925     | 0.0000
# 177        | 0.9927     | 0.0000
# 178        | 0.9928     | 0.0000
# 179        | 0.9928     | 0.0000
# 180        | 0.9930     | 0.0000
# 181        | 0.9931     | 0.0000
# 182        | 0.9931     | 0.0000
# 183        | 0.9929     | 0.0000
# 184        | 0.9931     | 0.0000
# 185        | 0.9931     | 0.0000
# 186        | 0.9933     | 0.0000
# 187        | 0.9935     | 0.0000
# 188        | 0.9934     | 0.0000
# 189        | 0.9934     | 0.0000
# 190        | 0.9937     | 0.0000
# 191        | 0.9937     | 0.0000
# 192        | 0.9937     | 0.0000
# 193        | 0.9935     | 0.0000
# 194        | 0.9938     | 0.0000
# 195        | 0.9937     | 0.0000
# 196        | 0.9939     | 0.0000
# 197        | 0.9938     | 0.0000
# 198        | 0.9938     | 0.0000
# 199        | 0.9940     | 0.0000
# 200        | 0.9939     | 0.0000
# 201        | 0.9940     | 0.0000
# 202        | 0.9941     | 0.0000
# 203        | 0.9941     | 0.0000
# 204        | 0.9938     | 0.0000
# 205        | 0.9941     | 0.0000
# 206        | 0.9946     | 0.0000
# 207        | 0.9947     | 0.0000
# 208        | 0.9947     | 0.0000
# 209        | 0.9950     | 0.0000
# 210        | 0.9951     | 0.0000
# 211        | 0.9954     | 0.0000
# 212        | 0.9953     | 0.0000
# 213        | 0.9954     | 0.0000
# 214        | 0.9956     | 0.0000
# 215        | 0.9958     | 0.0000
# 216        | 0.9960     | 0.0000
# 217        | 0.9962     | 0.0000
# 218        | 0.9963     | 0.0000
# 219        | 0.9962     | 0.0000
# 220        | 0.9963     | 0.0000
# 221        | 0.9964     | 0.0000
# 222        | 0.9967     | 0.0000
# 223        | 0.9968     | 0.0000
# 224        | 0.9968     | 0.0000
# 225        | 0.9969     | 0.0000
# 226        | 0.9971     | 0.0000
# 227        | 0.9971     | 0.0000
# 228        | 0.9971     | 0.0000
# 229        | 0.9972     | 0.0000
# 230        | 0.9972     | 0.0000
# 231        | 0.9972     | 0.0000
# 232        | 0.9975     | 0.0000
# 233        | 0.9975     | 0.0000
# 234        | 0.9975     | 0.0000
# 235        | 0.9976     | 0.0000
# 236        | 0.9976     | 0.0000
# 237        | 0.9975     | 0.0000
# 238        | 0.9976     | 0.0000
# 239        | 0.9976     | 0.0000
# 240        | 0.9977     | 0.0000
# 241        | 0.9975     | 0.0000
# 242        | 0.9977     | 0.0000
# 243        | 0.9978     | 0.0000
# 244        | 0.9979     | 0.0000
# 245        | 0.9980     | 0.0000
# 246        | 0.9980     | 0.0000
# 247        | 0.9978     | 0.0000
# 248        | 0.9980     | 0.0000
# 249        | 0.9981     | 0.0000
# 250        | 0.9981     | 0.0000
# 251        | 0.9981     | 0.0000
# 252        | 0.9981     | 0.0000
# 253        | 0.9981     | 0.0000
# 254        | 0.9980     | 0.0000
# 255        | 0.9979     | 0.0000
# 256        | 0.9981     | 0.0000
# 257        | 0.9982     | 0.0000
# 258        | 0.9981     | 0.0000
# 259        | 0.9981     | 0.0000
# 260        | 0.9982     | 0.0000
# 261        | 0.9981     | 0.0000
# 262        | 0.9983     | 0.0000
# 263        | 0.9982     | 0.0000
# 264        | 0.9983     | 0.0000
# 265        | 0.9983     | 0.0000
# 266        | 0.9983     | 0.0000
# 267        | 0.9982     | 0.0000
# 268        | 0.9983     | 0.0000
# 269        | 0.9983     | 0.0000
# 270        | 0.9983     | 0.0000
# 271        | 0.9983     | 0.0000
# 272        | 0.9982     | 0.0000
# 273        | 0.9983     | 0.0000
# 274        | 0.9984     | 0.0000
# 275        | 0.9984     | 0.0000
# 276        | 0.9983     | 0.0000
# 277        | 0.9984     | 0.0000
# 278        | 0.9982     | 0.0000
# 279        | 0.9985     | 0.0000
# 280        | 0.9985     | 0.0000
# 281        | 0.9985     | 0.0000
# 282        | 0.9984     | 0.0000
# 283        | 0.9984     | 0.0000
# 284        | 0.9984     | 0.0000
# 285        | 0.9985     | 0.0000
# 286        | 0.9985     | 0.0000
# 287        | 0.9985     | 0.0000
# 288        | 0.9984     | 0.0000
# 289        | 0.9985     | 0.0000
# 290        | 0.9985     | 0.0000
# 291        | 0.9984     | 0.0000
# 292        | 0.9985     | 0.0000
# 293        | 0.9985     | 0.0000
# 294        | 0.9985     | 0.0000
# 295        | 0.9985     | 0.0000
# 296        | 0.9986     | 0.0000
# 297        | 0.9986     | 0.0000
# 298        | 0.9986     | 0.0000
# 299        | 0.9986     | 0.0000
# 300        | 0.9986     | 0.0000
# 301        | 0.9985     | 0.0000
# 302        | 0.9984     | 0.0000
# 303        | 0.9986     | 0.0000
# 304        | 0.9986     | 0.0000
# 305        | 0.9986     | 0.0000
# 306        | 0.9986     | 0.0000
# 307        | 0.9985     | 0.0000
# 308        | 0.9987     | 0.0000
# 309        | 0.9987     | 0.0000
# 310        | 0.9987     | 0.0000
# 311        | 0.9987     | 0.0000
# 312        | 0.9988     | 0.0000
# 313        | 0.9987     | 0.0000
# 314        | 0.9987     | 0.0000
# 315        | 0.9987     | 0.0000
# 316        | 0.9988     | 0.0000
# 317        | 0.9988     | 0.0000
# 318        | 0.9988     | 0.0000
# 319        | 0.9988     | 0.0000
# 320        | 0.9988     | 0.0000
# 321        | 0.9988     | 0.0000
# 322        | 0.9989     | 0.0000
# 323        | 0.9989     | 0.0000
# 324        | 0.9990     | 0.0000
# 325        | 0.9990     | 0.0000
# 326        | 0.9990     | 0.0000
# 327        | 0.9990     | 0.0000
# WARNING - Objective function reached target fidelity = 0.999, exiting optimization...
# Optimization completed. Solution shape: torch.Size([16])
# Solution: tensor([ 0.7114,  0.3725,  0.9843,  1.4258,  0.4205,  0.6575,  1.1152,  0.7658,
#          0.8787, -0.6068,  0.7452,  0.8508, -0.6760, -0.0601, -0.5262, -0.8038],
#        dtype=torch.float64)

# %% [markdown]
# ## 2. Single Qubit with Multiple Initial/Target States
#
# Now let's try a more complex single qubit example with multiple initial and target states.

# %%
# Load single qubit multiple states configuration
single_multiple_api = load_single_qubit_multiple_config()

# Display configuration summary
print("Single Qubit Multiple States Configuration:")
print("=" * 50)
print(single_multiple_api.get_config_summary())
# Out:
# Single Qubit Multiple States Configuration:
# ==================================================
# Number of qubits: 1
# Optimization space: hilbert
# Algorithm: qiskit-cobyla
# Max iterations: 1000
# Target fidelity: 0.999
# Initial states: [['X'], ['Y'], ['Z']]
# Target Axis: [['X'], ['Z'], ['-Y']]

# %%
# Run the optimization
print("Running single qubit multiple states optimization...")
single_multiple_solution = single_multiple_api.run_optimization()
print(f"Optimization completed. Solution shape: {single_multiple_solution.shape}")
print(f"Solution: {single_multiple_solution}")
waveforms = process_and_plot(
    single_multiple_solution, single_multiple_api.parameters, show_plots=True
)
# Out:
# Number of threads set to 11 out of 12 available cores.
# =================================
# Iteration  | Fidelity   | Penalty
# =================================
# 1          | 0.3828     | 0.0000
# 2          | 0.5467     | 0.0000
# 3          | 0.5695     | 0.0000
# 4          | 0.3613     | 0.0000
# 5          | 0.4239     | 0.0000
# 6          | 0.3538     | 0.0000
# 7          | 0.3741     | 0.0000
# 8          | 0.7142     | 0.0000
# 9          | 0.6887     | 0.0000
# 10         | 0.6463     | 0.0000
# 11         | 0.7519     | 0.0000
# 12         | 0.5728     | 0.0000
# 13         | 0.3828     | 0.0000
# 14         | 0.4565     | 0.0000
# 15         | 0.5111     | 0.0000
# 16         | 0.8299     | 0.0000
# 17         | 0.8305     | 0.0000
# 18         | 0.6461     | 0.0000
# 19         | 0.9919     | 0.0000
# 20         | 0.8706     | 0.0000
# 21         | 0.9972     | 0.0000
# 22         | 0.4632     | 0.0000
# 23         | 0.8537     | 0.0000
# 24         | 0.5135     | 0.0000
# 25         | 0.9701     | 0.0000
# 26         | 0.4574     | 0.0000
# 27         | 0.7850     | 0.0000
# 28         | 0.6418     | 0.0000
# 29         | 0.9530     | 0.0000
# 30         | 0.6835     | 0.0000
# 31         | 0.9991     | 0.0000
# WARNING - Objective function reached target fidelity = 0.999, exiting optimization...
# Running single qubit multiple states optimization...
# Optimization completed. Solution shape: torch.Size([16])
# Solution: tensor([ 2.0455,  0.4918, -0.9339,  0.7766,  0.0797, -0.5301,  0.1938,  0.8662,
#          0.1784,  1.2652, -0.4375,  0.8817, -0.0185, -0.3613,  0.0330,  1.1484],
#        dtype=torch.float64)

# %% [markdown]
# ## 3. Two Qubit Optimization
#
# Let's move to a two qubit system optimization.

# %%
# Load two qubit configuration
two_qubit_api = load_two_qubit_config()

# Display configuration summary
print("Two Qubit Configuration:")
print("=" * 40)
print(two_qubit_api.get_config_summary())
# Out:
# Two Qubit Configuration:
# ========================================
# Number of qubits: 2
# Optimization space: hilbert
# Algorithm: newton-cg
# Max iterations: 1000
# Target fidelity: 0.999
# Initial states: [['Z', '-Z']]
# Target Gate: ['CNOT']

# %%
# Run the optimization
print("Running two qubit optimization...")
two_qubit_solution = two_qubit_api.run_optimization()
print(f"Optimization completed. Solution shape: {two_qubit_solution.shape}")
print(f"Solution: {two_qubit_solution}")
waveforms = process_and_plot(
    two_qubit_solution, two_qubit_api.parameters, show_plots=True
)

# %% [markdown]
# ## 4. Two Qubit with Multiple Initial/Target States
#
# Finally, let's try the most complex example with two qubits and multiple states.

# %%
# Load two qubit multiple states configuration
two_multiple_api = load_two_qubit_multiple_config()

# Display configuration summary
print("Two Qubit Multiple States Configuration:")
print("=" * 50)
print(two_multiple_api.get_config_summary())

# %%
# Run the optimization
print("Running two qubit multiple states optimization...")
two_multiple_solution = two_multiple_api.run_optimization()
print(f"Optimization completed. Solution shape: {two_multiple_solution.shape}")
print(f"Solution: {two_multiple_solution}")
waveforms = process_and_plot(
    two_multiple_solution, two_multiple_api.parameters, show_plots=True
)

# %% [markdown]
# ## 5. Loading Custom Configurations
#
# You can also load custom configuration files or create configurations programmatically.

# %%
# Example: Load a configuration from a file path
custom_api = load_config(
    "../src/ctrl_freeq/data/json_input/single_qubit_parameters.json"
)
print("Custom loaded configuration:")
print(custom_api.get_config_summary())

# %%
# Example: Modify parameters before running
custom_api.update_parameter("optimization.max_iter", 500)
custom_api.update_parameter("optimization.targ_fid", 0.995)

print("Modified configuration:")
print(custom_api.get_config_summary())

# %% [markdown]
# ## 6. Direct Configuration Usage
#
# For quick runs, you can use the `run_from_config` function directly.

# %%
# Run directly from a configuration file
print("Running optimization directly from config file...")
direct_solution = run_from_config(
    "../src/ctrl_freeq/data/json_input/single_qubit_parameters.json"
)
print(f"Direct optimization completed. Solution: {direct_solution}")

# %% [markdown]
# ## 7. Visualization of Solutions
#
# Let's create some basic visualizations of the optimization solutions.

# %%
# Plot the solutions
fig, axes = plt.subplots(2, 2, figsize=(12, 10))
fig.suptitle("CtrlFreeQ Optimization Solutions", fontsize=16)

# Single qubit solution
axes[0, 0].plot(single_qubit_solution.detach().numpy())
axes[0, 0].set_title("Single Qubit Solution")
axes[0, 0].set_xlabel("Parameter Index")
axes[0, 0].set_ylabel("Value")
axes[0, 0].grid(True)

# Single qubit multiple states solution
axes[0, 1].plot(single_multiple_solution.detach().numpy())
axes[0, 1].set_title("Single Qubit Multiple States Solution")
axes[0, 1].set_xlabel("Parameter Index")
axes[0, 1].set_ylabel("Value")
axes[0, 1].grid(True)

# Two qubit solution
axes[1, 0].plot(two_qubit_solution.detach().numpy())
axes[1, 0].set_title("Two Qubit Solution")
axes[1, 0].set_xlabel("Parameter Index")
axes[1, 0].set_ylabel("Value")
axes[1, 0].grid(True)

# Two qubit multiple states solution
axes[1, 1].plot(two_multiple_solution.detach().numpy())
axes[1, 1].set_title("Two Qubit Multiple States Solution")
axes[1, 1].set_xlabel("Parameter Index")
axes[1, 1].set_ylabel("Value")
axes[1, 1].grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Summary
#
# This notebook demonstrated how to use the CtrlFreeQ API to:
#
# 1. Load different types of quantum control configurations
# 2. Run CtrlFreeQ optimizations with minimal code
# 3. Inspect configuration parameters
# 4. Modify parameters before optimization
# 5. Visualize optimization results
#
# The API provides a clean interface to the powerful CtrlFreeQ quantum control optimization framework, making it easy to set up and run quantum control experiments.
